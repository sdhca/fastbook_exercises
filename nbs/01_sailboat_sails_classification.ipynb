# %% [markdown]
# # Sailboat Classifier
#
# Multi-label classifier for predicting if sailboats have their mainsail, jib, and/or spinnaker hoisted.
#
# Inspired by [Fast AI Fastbook Lesson 1](https://course.fast.ai/Lessons/lesson1.html) and [the reference notebook](https://www.kaggle.com/code/jhoward/is-it-a-bird-creating-a-model-from-your-own-data).
#
# Basic steps:
# 1. Download and preprocess sailboat photos using Bing
#    - In limited testing, Bing appeared to provide better photos than Duck Duck Go. See [01_compare_images_sources.ipynb](https://github.com/sdhca/fastbook_exercises/blob/main/01_compare_image_sources.ipynb)
#
# 2. Label photos using [Label Studio](https://labelstud.io/) outside this notebook
#    - Training images with positive labels will be restricted to only those photos showing a single sailboat.
#
# 3. Fine-tune a pretrained model

# %%
do_search_and_download = False

from fastai.vision.all import resnet34

# PARAMS contains only hyperparameters relevant for tuning and tracking in Neptune
use_neptune = True
neptune_project_name = 'sdhca/fastbook-exercise-01'
PARAMS = {'batch_size': 64,
         'n_epochs': 20,
         'base_lr': 0.0025,
         'nn_arch': resnet34}

# %% [markdown]
# # Search & Download Photos

# %% [markdown]
# ## Bing Search
# Note that a [forked version of bing_images](https://github.com/sdhca/bing_images/tree/compatibility_updates) has been used.

# %%
from bing_images import bing

def search_images_with_bing(term, max_images=20, filters=''):
    print(f"Searching for '{term}'")
    return bing.fetch_image_urls(term, limit=max_images, filters=filters)

# %%
# %%time
if do_search_and_download:
    urls = search_images_with_bing('sailboat', max_images=500, filters='+filterui:photo')
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ## Check One Image

# %%
from fastai.vision.all import Image
from urllib.parse import urlparse
from typing import Optional
import requests

def url_to_image(url: str, size: Optional[int]=None) -> Image:
    try:
        im = Image.open(requests.get(url, stream=True).raw)
    except:
        return None
    
    if size is not None:
        (iw, ih) = im.size
        im = im.crop_pad(min(iw, ih))
        im = im.resize((size, size))
        
    im.filename = urlparse(url).path
    
    return im

# %%
if do_search_and_download:
    print(urls[0])
    test_image = url_to_image(urls[0], size=256)
    test_image.to_thumb(256, 256)

# %% [markdown]
# ## Download All Images

# %%
from fastdownload import download_url
from pathlib import Path
from fastai.vision.utils import download_images

image_path = Path('sailboat_photos')
raw_path = image_path/'raw'
raw_path.mkdir(exist_ok=True, parents=True)
if do_search_and_download:
    download_images(raw_path, urls=urls)

# %% [markdown]
# ## Preprocess Images
# Resize images

# %%
from fastai.vision.utils import resize_images

proc_path = image_path/'preprocessed'
proc_path.mkdir(exist_ok=True, parents=True)

if do_search_and_download:
    resize_images(raw_path, max_size=256, dest=proc_path)

# %% [markdown]
# # Label Photos using Label Studio

# %% [markdown]
# Photos were labelled in Label Studio using this template:
#
# `<View>
#   <Image name="image" value="$image" rotateControl="false"/>
#   <Choices name="choice" toName="image" choice="multiple">
#     <Choice value="Main"/>
#     <Choice value="Jib"/>
#     <Choice value="Spinnaker"/>
#     <Choice value="Reject Photo"/>
#   </Choices>
# </View>`

# %%
import pandas as pd

df_labels_raw = pd.read_csv(image_path/'project-4-at-2022-11-14-23-12-b3dd4eaa.csv')
df_labels_raw
# Out:
#                                                                  image   id  \
# 0     /data/upload/4/f762d119-fffa5987-12a6-4849-8703-63625f41e010.jpg  761
# 1    /data/upload/4/f44096d4-ff782537-9085-4721-ab0d-f938a5baa1d0.jpeg  760
# 2     /data/upload/4/51dfc561-ff71fbef-6bf7-4212-9c66-0d65f3978cde.jpg  759
# 3     /data/upload/4/b53bf771-ff43b12e-1d47-412c-a8cf-286dfe141a01.jpg  758
# 4     /data/upload/4/0f14b7e8-ff8b9eda-3b61-48d3-b087-f669f93379bf.jpg  757
# ..                                                                 ...  ...
# 434   /data/upload/4/cc5a8a00-0ddf520f-be10-4ba5-ae70-f75967a870f9.JPG  327
# 435   /data/upload/4/a607c40c-0d5a0a76-0ba2-4e53-9e62-4fd78259afbf.jpg  326
# 436   /data/upload/4/bc7e0ed8-0c9b5cd4-a67b-4184-83c1-146e4d62502a.jpg  325
# 437   /data/upload/4/84f7334d-0b9abcc7-4ca4-4410-8b1f-75711a313bfa.jpg  324
# 438   /data/upload/4/891d80e6-0ab362c0-3327-44d2-8015-722b8c96ecb3.jpg  323
#
#                            choice  annotator  annotation_id  \
# 0    {"choices": ["Main", "Jib"]}          1            762
# 1                             NaN          1            761
# 2                             NaN          1            760
# 3                    Reject Photo          1            759
# 4    {"choices": ["Main", "Jib"]}          1            758
# ..                            ...        ...            ...
# 434                           NaN          1            328
# 435  {"choices": ["Main", "Jib"]}          1            327
# 436                           NaN          1            326
# 437  {"choices": ["Main", "Jib"]}          1            325
# 438                           NaN          1            324
#
#                       created_at                   updated_at  lead_time
# 0    2022-11-15T04:11:29.256285Z  2022-11-15T04:11:29.256285Z      1.590
# 1    2022-11-15T04:11:27.342191Z  2022-11-15T04:11:27.342191Z      0.866
# 2    2022-11-15T04:11:25.869387Z  2022-11-15T04:11:25.869387Z      0.983
# 3    2022-11-15T04:11:24.524713Z  2022-11-15T04:11:24.524713Z      5.051
# 4    2022-11-15T04:11:18.864808Z  2022-11-15T04:11:18.864808Z      1.152
# ..                           ...                          ...        ...
# 434  2022-11-15T03:53:53.599265Z  2022-11-15T03:53:53.599265Z      1.147
# 435  2022-11-15T03:53:52.050673Z  2022-11-15T03:53:52.050673Z      1.788
# 436  2022-11-15T03:53:49.854320Z  2022-11-15T03:53:49.854320Z     11.494
# 437  2022-11-15T03:53:37.975283Z  2022-11-15T03:53:37.975283Z     10.618
# 438  2022-11-15T03:53:27.001933Z  2022-11-15T03:53:27.001933Z      4.219
#
# [439 rows x 8 columns]

# %%
df_labels = df_labels_raw[['image', 'choice']].copy()
df_labels['choice'] = df_labels['choice'].replace('\{"choices": \[|]\}|"|,', '', regex=True)
df_labels['choice'] = df_labels['choice'].fillna('')
df_labels = df_labels[df_labels['choice'] != 'Reject Photo']
df_labels['image'] = df_labels['image'].replace('^/data/upload/4/[^-]*-', '', regex=True)

# %%
df_labels
# Out:
#                                          image    choice
# 0     fffa5987-12a6-4849-8703-63625f41e010.jpg  Main Jib
# 1    ff782537-9085-4721-ab0d-f938a5baa1d0.jpeg
# 2     ff71fbef-6bf7-4212-9c66-0d65f3978cde.jpg
# 4     ff8b9eda-3b61-48d3-b087-f669f93379bf.jpg  Main Jib
# 5     fea607d8-dbc9-4faa-9f15-46752a806213.jpg  Main Jib
# ..                                         ...       ...
# 434   0ddf520f-be10-4ba5-ae70-f75967a870f9.JPG
# 435   0d5a0a76-0ba2-4e53-9e62-4fd78259afbf.jpg  Main Jib
# 436   0c9b5cd4-a67b-4184-83c1-146e4d62502a.jpg
# 437   0b9abcc7-4ca4-4410-8b1f-75711a313bfa.jpg  Main Jib
# 438   0ab362c0-3327-44d2-8015-722b8c96ecb3.jpg
#
# [424 rows x 2 columns]

# %%
df_labels.groupby('choice').agg('count')
# Out:
#                     image
# choice
#                        93
# Jib                     3
# Main                   56
# Main Jib              222
# Main Jib Spinnaker     12
# Main Spinnaker         37
# Spinnaker               1

# %% [markdown]
# # Train Model

# %%
# %load_ext dotenv
# %dotenv

# %%
import neptune.new as neptune
from neptune.new.integrations.fastai import NeptuneCallback
from neptune.new.types import File
import warnings

warnings.filterwarnings('ignore', message='The object you\'re logging will be implicitly cast to a string.')

if use_neptune:
    run = neptune.init_run(project=neptune_project_name)
    run['parameters']=PARAMS
    neptune_callback = NeptuneCallback(run=run)
# Out:
# https://app.neptune.ai/sdhca/fastbook-exercise-01/e/FBEX01-30
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api/run#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %%
from fastai.vision.all import DataBlock, ImageBlock, MultiCategoryBlock, ColReader, RandomSplitter, Resize

image_size = 192

dls = DataBlock(
    blocks=(ImageBlock, MultiCategoryBlock),
    get_x=ColReader(0, pref=proc_path),
#     get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=ColReader(1, label_delim=' '),
    item_tfms=[Resize(image_size, method='squish')]
).dataloaders(df_labels, batch_size=PARAMS['batch_size'])

dls.show_batch(max_n=6)

# %%
warnings.filterwarnings('ignore', message='The parameter \'pretrained\' is deprecated since 0.13 and may be removed in the future, please use \'weights\' instead.')
warnings.filterwarnings('ignore', message='Arguments other than a weight enum or `None` for \'weights\' are deprecated')
warnings.filterwarnings('ignore', message='NeptuneCallback: SaveModelCallback is necessary for uploading model checkpoints.')
warnings.filterwarnings('ignore', message='The object you\'re logging will be implicitly cast to a string.')

from fastai.vision.all import vision_learner, accuracy_multi

learn = None
if use_neptune:
    learn = vision_learner(dls, PARAMS['nn_arch'], metrics=accuracy_multi, cbs=neptune_callback)
else:
    learn = vision_learner(dls, PARAMS['nn_arch'], metrics=accuracy_multi)

# %%
from fastai.vision.all import BCEWithLogitsLossFlat
learn.loss_func = BCEWithLogitsLossFlat()
# learn.lr_find()

# %%
# from neptune.init import NeptuneDepricationWarning
import warnings
# warnings.filterwarnings(action='ignore', category=NeptuneDepricationWarning, module='neptune.new')
learn.fine_tune(PARAMS['n_epochs'], base_lr=PARAMS['base_lr'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.937372</td>
#       <td>1.184499</td>
#       <td>0.507937</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.676063</td>
#       <td>0.764046</td>
#       <td>0.650794</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.578147</td>
#       <td>0.616962</td>
#       <td>0.714286</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.509318</td>
#       <td>0.549632</td>
#       <td>0.773810</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.443762</td>
#       <td>0.527437</td>
#       <td>0.809524</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.389076</td>
#       <td>0.500774</td>
#       <td>0.817460</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.340162</td>
#       <td>0.473147</td>
#       <td>0.829365</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.299691</td>
#       <td>0.443080</td>
#       <td>0.837302</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.260189</td>
#       <td>0.410471</td>
#       <td>0.869048</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.226148</td>
#       <td>0.401371</td>
#       <td>0.884921</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.200834</td>
#       <td>0.387957</td>
#       <td>0.876984</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.176924</td>
#       <td>0.346677</td>
#       <td>0.876984</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.157181</td>
#       <td>0.333463</td>
#       <td>0.884921</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.139989</td>
#       <td>0.324136</td>
#       <td>0.888889</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.124905</td>
#       <td>0.308950</td>
#       <td>0.888889</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.112437</td>
#       <td>0.295026</td>
#       <td>0.884921</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.101156</td>
#       <td>0.291048</td>
#       <td>0.892857</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.091844</td>
#       <td>0.285685</td>
#       <td>0.888889</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.083216</td>
#       <td>0.281756</td>
#       <td>0.892857</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.075933</td>
#       <td>0.277704</td>
#       <td>0.896825</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.069014</td>
#       <td>0.269848</td>
#       <td>0.904762</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
if use_neptune:
    run.stop()

learn.remove_cbs(neptune_callback)
learn.export('sailboat_sails_classification.pkl')
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 9 operations to synchronize with Neptune. Do not kill this process.
# All 9 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/sdhca/fastbook-exercise-01/e/FBEX01-30

# %%
learn.show_results()

# %%
from fastai.vision.all import ClassificationInterpretation

interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(25)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>predicted</th>
#       <th>probabilities</th>
#       <th>loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Jib;Main</td>
#       <td></td>
#       <td>TensorBase([1.8591e-01, 7.8077e-05, 1.6008e-02])</td>
#       <td>3.7198894023895264</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Spinnaker</td>
#       <td>Main;Spinnaker</td>
#       <td>TensorBase([0.0648, 0.9991, 1.0000])</td>
#       <td>2.371950149536133</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Jib;Main</td>
#       <td></td>
#       <td>TensorBase([0.4564, 0.0198, 0.1304])</td>
#       <td>1.6156363487243652</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Jib;Main</td>
#       <td></td>
#       <td>TensorBase([0.4387, 0.0246, 0.2223])</td>
#       <td>1.593280553817749</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Main;Spinnaker</td>
#       <td>Jib;Main;Spinnaker</td>
#       <td>TensorBase([0.9451, 0.9968, 1.0000])</td>
#       <td>0.968829333782196</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Main;Spinnaker</td>
#       <td>Jib;Main;Spinnaker</td>
#       <td>TensorBase([0.9116, 0.9997, 0.8043])</td>
#       <td>0.8815934062004089</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Main;Spinnaker</td>
#       <td>Jib;Main;Spinnaker</td>
#       <td>TensorBase([0.9256, 0.9920, 0.9972])</td>
#       <td>0.8688251376152039</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Jib;Main</td>
#       <td>Main;Spinnaker</td>
#       <td>TensorBase([0.3506, 0.9921, 0.7137])</td>
#       <td>0.7686361074447632</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Jib;Main</td>
#       <td>Jib</td>
#       <td>TensorBase([0.9551, 0.1096, 0.0435])</td>
#       <td>0.7672945857048035</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Jib;Main</td>
#       <td></td>
#       <td>TensorBase([0.2897, 0.4034, 0.0202])</td>
#       <td>0.7212655544281006</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Main;Spinnaker</td>
#       <td>Jib;Main;Spinnaker</td>
#       <td>TensorBase([0.8230, 0.9686, 0.6979])</td>
#       <td>0.7074992060661316</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td></td>
#       <td>Main</td>
#       <td>TensorBase([0.4728, 0.7469, 0.0874])</td>
#       <td>0.7012723684310913</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Jib;Main</td>
#       <td>Main</td>
#       <td>TensorBase([0.1766, 0.9539, 0.2747])</td>
#       <td>0.7001127004623413</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Main</td>
#       <td>Main;Spinnaker</td>
#       <td>TensorBase([0.0225, 0.9768, 0.8276])</td>
#       <td>0.6014347076416016</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td></td>
#       <td>Jib</td>
#       <td>TensorBase([0.7623, 0.2365, 0.0164])</td>
#       <td>0.5743482112884521</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Main;Spinnaker</td>
#       <td>Jib;Main;Spinnaker</td>
#       <td>TensorBase([0.7265, 0.9968, 0.7333])</td>
#       <td>0.5360281467437744</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Jib;Main</td>
#       <td>Jib;Main</td>
#       <td>TensorBase([0.5100, 0.9984, 0.4898])</td>
#       <td>0.44938045740127563</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Jib;Main;Spinnaker</td>
#       <td>Main;Spinnaker</td>
#       <td>TensorBase([0.3029, 0.9996, 1.0000])</td>
#       <td>0.39786550402641296</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Main;Spinnaker</td>
#       <td>Jib;Main;Spinnaker</td>
#       <td>TensorBase([0.5643, 0.9995, 1.0000])</td>
#       <td>0.27696874737739563</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Jib;Main</td>
#       <td>Jib;Main</td>
#       <td>TensorBase([0.5307, 0.8747, 0.0214])</td>
#       <td>0.2627612054347992</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Main</td>
#       <td>Main;Spinnaker</td>
#       <td>TensorBase([0.0320, 0.9998, 0.5244])</td>
#       <td>0.2585539221763611</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Jib;Main</td>
#       <td>Jib;Main</td>
#       <td>TensorBase([0.9350, 0.5687, 0.0896])</td>
#       <td>0.24219822883605957</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Jib;Main</td>
#       <td>Jib;Main</td>
#       <td>TensorBase([0.9888, 0.9959, 0.4993])</td>
#       <td>0.23574881255626678</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Main</td>
#       <td>Main</td>
#       <td>TensorBase([0.4947, 0.9837, 0.0042])</td>
#       <td>0.2337447702884674</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Jib;Main</td>
#       <td>Jib;Main</td>
#       <td>TensorBase([0.9927, 0.8910, 0.2920])</td>
#       <td>0.15619127452373505</td>
#     </tr>
#   </tbody>
# </table>

# %%
# This function does not work for multi-label classification
# interp.plot_confusion_matrix()

# %%
# from sklearn.metrics import multilabel_confusion_matrix
# multilabel_confusion_matrix(learn.get_preds()[1], samplewise=True, labels=learn.dls.vocab)

# %%
learn.dls.vocab
# Out:
# ['Jib', 'Main', 'Spinnaker']
